# %%
# disable tensorflow warnings and errors
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import tensorflow as tf
import pandas as pd
import seaborn as sn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Sequential

# %%
rawdf = pd.read_csv(os.path.join(os.getcwd(), "StressLevelDataset.csv"), encoding="utf8")
rawdf.info()
rawdf.drop(columns=["teacher_student_relationship", "stress_level"], axis=1, inplace=True) # see readme on why this is removed
# check for null data before continuing with preprocessing
rawdf.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
#  13  study_load                    1100 non-null   int64
#  14  teacher_student_relationship  1100 non-null   int64
#  15  future_career_concerns        1100 non-null   int64
#  16  social_support                1100 non-null   int64
#  17  peer_pressure                 1100 non-null   int64
#  18  extracurricular_activities    1100 non-null   int64
#  19  bullying                      1100 non-null   int64
#  20  stress_level                  1100 non-null   int64
# dtypes: int64(21)
# memory usage: 180.6 KB
# anxiety_level                 0
# self_esteem                   0
# mental_health_history         0
# depression                    0
# headache                      0
# blood_pressure                0
# sleep_quality                 0
# breathing_problem             0
# noise_level                   0
# living_conditions             0
# safety                        0
# basic_needs                   0
# academic_performance          0
# study_load                    0
# future_career_concerns        0
# social_support                0
# peer_pressure                 0
# extracurricular_activities    0
# bullying                      0
# dtype: int64

# %%
# define our labels and features into variables
main_label = "anxiety_level"
main_features = rawdf.columns.values.tolist()
main_features.remove(main_label)

print(f"Label: {main_label}\nFeatures: {main_features}")
# Out:
# Label: anxiety_level
# Features: ['self_esteem', 'mental_health_history', 'depression', 'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem', 'noise_level', 'living_conditions', 'safety', 'basic_needs', 'academic_performance', 'study_load', 'future_career_concerns', 'social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']

# %%
# look at our dataset before choosing type of preprocessing (normalization or standardization)
rawdf.head(10)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
# 5             20           13                      1          21         3
# 6              4           26                      0           6         1
# 7             17            3                      1          22         4
# 8             13           22                      1          12         3
# 9              6            8                      0          27         4
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
# 5               3              1                  4            3
# 6               2              4                  1            1
# 7               3              1                  5            3
# 8               1              2                  4            3
# 9               3              1                  2            0
#
#    living_conditions  safety  basic_needs  academic_performance  study_load  \
# 0                  3       3            2                     3           2
# 1                  1       2            2                     1           4
# 2                  2       3            2                     2           3
# 3                  2       2            2                     2           4
# 4                  2       4            3                     4           3
# 5                  2       2            1                     2           5
# 6                  4       4            4                     5           1
# 7                  1       1            1                     1           3
# 8                  3       3            3                     3           3
# 9                  5       2            2                     2           2
#
#    future_career_concerns  social_support  peer_pressure  \
# 0                       3               2              3
# 1                       5               1              4
# 2                       2               2              3
# 3                       4               1              4
# 4                       2               1              5
# 5                       5               1              4
# 6                       1               3              2
# 7                       4               1              4
# 8                       3               3              3
# 9                       5               1              5
#
#    extracurricular_activities  bullying
# 0                           3         2
# 1                           5         5
# 2                           2         2
# 3                           4         5
# 4                           0         5
# 5                           4         5
# 6                           2         1
# 7                           4         5
# 8                           2         2
# 9                           3         4

# %%
# we will need this later for adjusting model's response
print(f"anxiety level:\n\tmin: {rawdf[main_label].min()}\n\tmax: {rawdf[main_label].max()}")
# Out:
# anxiety level:
# 	min: 0
# 	max: 21

# %%
# normalize the dataset
normalizer = MinMaxScaler(feature_range=(0, 1))
dfnormarr = normalizer.fit_transform(rawdf)
newdf = pd.DataFrame(dfnormarr, index=rawdf.index, columns=rawdf.columns)

# %%
newdf.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0       0.666667     0.666667                    0.0    0.407407       0.4
# 1       0.714286     0.266667                    1.0    0.555556       1.0
# 2       0.571429     0.600000                    1.0    0.518519       0.4
# 3       0.761905     0.400000                    1.0    0.555556       0.8
# 4       0.761905     0.933333                    0.0    0.259259       0.4
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0             0.0            0.4                0.8          0.4
# 1             1.0            0.2                0.8          0.6
# 2             0.0            0.4                0.4          0.4
# 3             1.0            0.2                0.6          0.8
# 4             1.0            1.0                0.2          0.6
#
#    living_conditions  safety  basic_needs  academic_performance  study_load  \
# 0                0.6     0.6          0.4                   0.6         0.4
# 1                0.2     0.4          0.4                   0.2         0.8
# 2                0.4     0.6          0.4                   0.4         0.6
# 3                0.4     0.4          0.4                   0.4         0.8
# 4                0.4     0.8          0.6                   0.8         0.6
#
#    future_career_concerns  social_support  peer_pressure  \
# 0                     0.6        0.666667            0.6
# 1                     1.0        0.333333            0.8
# 2                     0.4        0.666667            0.6
# 3                     0.8        0.333333            0.8
# 4                     0.4        0.333333            1.0
#
#    extracurricular_activities  bullying
# 0                         0.6       0.4
# 1                         1.0       1.0
# 2                         0.4       0.4
# 3                         0.8       1.0
# 4                         0.0       1.0

# %%
# check for negative numbers
print((newdf.values < 0).any())
# Out:
# False

# %%
# # numpy implementation
# # the data does not have the same maximum/minimum per column so we will standardize
# scaler = MinMaxScaler()
# newdf = scaler.fit_transform(rawdf)

# labelindex = rawdf.columns.get_loc(main_label)

# rawfeatures = np.delete(newdf, labelindex, axis=1) # get all arrays based on the rule given
# rawlabels = newdf[:, labelindex] # access column with the label based on its index

# print(rawfeatures)
# print(np.info(rawfeatures))

# print(rawlabels)
# print(np.info(rawlabels))

# %%
newdf.head(10)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0       0.666667     0.666667                    0.0    0.407407       0.4
# 1       0.714286     0.266667                    1.0    0.555556       1.0
# 2       0.571429     0.600000                    1.0    0.518519       0.4
# 3       0.761905     0.400000                    1.0    0.555556       0.8
# 4       0.761905     0.933333                    0.0    0.259259       0.4
# 5       0.952381     0.433333                    1.0    0.777778       0.6
# 6       0.190476     0.866667                    0.0    0.222222       0.2
# 7       0.809524     0.100000                    1.0    0.814815       0.8
# 8       0.619048     0.733333                    1.0    0.444444       0.6
# 9       0.285714     0.266667                    0.0    1.000000       0.8
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0             0.0            0.4                0.8          0.4
# 1             1.0            0.2                0.8          0.6
# 2             0.0            0.4                0.4          0.4
# 3             1.0            0.2                0.6          0.8
# 4             1.0            1.0                0.2          0.6
# 5             1.0            0.2                0.8          0.6
# 6             0.5            0.8                0.2          0.2
# 7             1.0            0.2                1.0          0.6
# 8             0.0            0.4                0.8          0.6
# 9             1.0            0.2                0.4          0.0
#
#    living_conditions  safety  basic_needs  academic_performance  study_load  \
# 0                0.6     0.6          0.4                   0.6         0.4
# 1                0.2     0.4          0.4                   0.2         0.8
# 2                0.4     0.6          0.4                   0.4         0.6
# 3                0.4     0.4          0.4                   0.4         0.8
# 4                0.4     0.8          0.6                   0.8         0.6
# 5                0.4     0.4          0.2                   0.4         1.0
# 6                0.8     0.8          0.8                   1.0         0.2
# 7                0.2     0.2          0.2                   0.2         0.6
# 8                0.6     0.6          0.6                   0.6         0.6
# 9                1.0     0.4          0.4                   0.4         0.4
#
#    future_career_concerns  social_support  peer_pressure  \
# 0                     0.6        0.666667            0.6
# 1                     1.0        0.333333            0.8
# 2                     0.4        0.666667            0.6
# 3                     0.8        0.333333            0.8
# 4                     0.4        0.333333            1.0
# 5                     1.0        0.333333            0.8
# 6                     0.2        1.000000            0.4
# 7                     0.8        0.333333            0.8
# 8                     0.6        1.000000            0.6
# 9                     1.0        0.333333            1.0
#
#    extracurricular_activities  bullying
# 0                         0.6       0.4
# 1                         1.0       1.0
# 2                         0.4       0.4
# 3                         0.8       1.0
# 4                         0.0       1.0
# 5                         0.8       1.0
# 6                         0.4       0.2
# 7                         0.8       1.0
# 8                         0.4       0.4
# 9                         0.6       0.8

# %%
# split dataframe into features and labels before split
featuresdf = newdf[main_features]
labelsdf = newdf[main_label]

# %%
#split the big dataframe into train/validation sets
trainx, testx, trainy, testy = train_test_split(featuresdf.to_numpy(), labelsdf.to_numpy(), train_size=0.8, test_size=0.2)

# %%
type(trainx)
# Out:
# numpy.ndarray

# %%
print(f"trainx: {trainx.shape}, testx: {testx.shape}, trainy: {trainy.shape}, testy: {testy.shape}")
# Out:
# trainx: (880, 18), testx: (220, 18), trainy: (880,), testy: (220,)

# %%
model = Sequential([
    Input(shape=trainx.shape[1]), #number of features is input shape
    Dense(64, activation="relu"),
    Dropout(0.2), # prevent model from adapting to training data
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(64, activation="relu"),
    Dense(1, activation="linear") # potentially 1 for every number in gad-7 scale
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1216
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9601 (37.50 KB)
# Trainable params: 9601 (37.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mean_squared_error", metrics=["accuracy"])

# %%
model.fit(trainx, trainy, epochs=30)
# Out:
# Epoch 1/30
# 28/28 [==============================] - 2s 5ms/step - loss: 0.0932 - accuracy: 0.0773
# Epoch 2/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0430 - accuracy: 0.0830
# Epoch 3/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0391 - accuracy: 0.0784
# Epoch 4/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 0.0841
# Epoch 5/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0335 - accuracy: 0.0830
# Epoch 6/30
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0352 - accuracy: 0.0795
# Epoch 7/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0312 - accuracy: 0.0852
# Epoch 8/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0310 - accuracy: 0.0864
# Epoch 9/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0313 - accuracy: 0.0886
# Epoch 10/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0317 - accuracy: 0.0841
# Epoch 11/30
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0318 - accuracy: 0.0841
# Epoch 12/30
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.0864
# Epoch 13/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0297 - accuracy: 0.0852
# Epoch 14/30
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0313 - accuracy: 0.0841
# Epoch 15/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 0.0875
# Epoch 16/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0290 - accuracy: 0.0886
# Epoch 17/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 0.0864
# Epoch 18/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 0.0864
# Epoch 19/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0289 - accuracy: 0.0875
# Epoch 20/30
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.0852
# Epoch 21/30
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.0875
# Epoch 22/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.0875
# Epoch 23/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0286 - accuracy: 0.0875
# Epoch 24/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.0875
# Epoch 25/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0271 - accuracy: 0.0886
# Epoch 26/30
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 0.0852
# Epoch 27/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0282 - accuracy: 0.0852
# Epoch 28/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0255 - accuracy: 0.0886
# Epoch 29/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 0.0886
# Epoch 30/30
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 0.0886

# %%
loss, accuracy = model.evaluate(testx, testy, verbose=2)
print(f'test loss: {loss:.0%} ({str(loss)[:5]})')
print(f'test accuracy: {accuracy:.0%} ({str(accuracy)[:5]})')
# small loss & accuracy means model makes small errors on a lot of data
# see https://datascience.stackexchange.com/questions/42599/what-is-the-relationship-between-the-accuracy-and-the-loss-in-deep-learning
# Out:
# 7/7 - 0s - loss: 0.0289 - accuracy: 0.0455 - 108ms/epoch - 15ms/step
# test loss: 3% (0.028)
# test accuracy: 5% (0.045)

# %%
validation = model.evaluate(testx, testy, verbose=2)
type(validation)
print(validation)
# Out:
# 7/7 - 0s - loss: 0.0289 - accuracy: 0.0455 - 44ms/epoch - 6ms/step
# [0.028861641883850098, 0.04545454680919647]

# %%
df_test = newdf.sample()
df_test.reset_index(drop=True, inplace=True)
df_test.drop(columns=[main_label], axis=1, inplace=True)
df_test.head()
# Out:
#    self_esteem  mental_health_history  depression  headache  blood_pressure  \
# 0          0.1                    1.0    0.888889       1.0             1.0
#
#    sleep_quality  breathing_problem  noise_level  living_conditions  safety  \
# 0            0.2                0.6          0.6                0.4     0.2
#
#    basic_needs  academic_performance  study_load  future_career_concerns  \
# 0          0.4                   0.2         0.8                     0.8
#
#    social_support  peer_pressure  extracurricular_activities  bullying
# 0        0.333333            1.0                         1.0       0.8

# %%
check = model.predict(df_test)
print(check)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[0.6303442]]

# %%
type(check)
# Out:
# numpy.ndarray

# %%
# this sucks but inverse_transforms requires that we add back all our existing features/label before giving us the original data
df_test.insert(0, main_label, check, True) # dataframe way
resultarr = normalizer.inverse_transform(df_test)
df_result = pd.DataFrame(resultarr, columns=df_test.columns, index=df_test.index)

# %%
df_result.head(10)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0      13.237228          3.0                    1.0        24.0       5.0
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0             3.0            1.0                3.0          3.0
#
#    living_conditions  safety  basic_needs  academic_performance  study_load  \
# 0                2.0     1.0          2.0                   1.0         4.0
#
#    future_career_concerns  social_support  peer_pressure  \
# 0                     4.0             1.0            5.0
#
#    extracurricular_activities  bullying
# 0                         5.0       4.0

# %%
anxiety_scaled = float(df_result.loc[0, main_label]) # numpy to python float
print(f"Raw Guess: {check[0][0]}, GAD-7 Scaled Guess: {anxiety_scaled:.2f}")
# Out:
# Raw Guess: 0.6303442120552063, GAD-7 Scaled Guess: 13.24
